# %%
import xlrd
import time
import pandas as pd
import smtplib
import time
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from pretty_html_table import build_table
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44628/2378784349.py in <module>
#       1 import xlrd
#       2 import time
# ----> 3 import pandas as pd
#       4 import smtplib
#       5 import time
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\__init__.py in <module>
#      48 import pandas.core.config_init
#      49
# ---> 50 from pandas.core.api import (
#      51     # dtype
#      52     Int8Dtype,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\api.py in <module>
#      46 from pandas.core.construction import array
#      47 from pandas.core.flags import Flags
# ---> 48 from pandas.core.groupby import (
#      49     Grouper,
#      50     NamedAgg,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\groupby\__init__.py in <module>
# ----> 1 from pandas.core.groupby.generic import (
#       2     DataFrameGroupBy,
#       3     NamedAgg,
#       4     SeriesGroupBy,
#       5 )
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\groupby\generic.py in <module>
#      71 import pandas.core.common as com
#      72 from pandas.core.construction import create_series_with_explicit_dtype
# ---> 73 from pandas.core.frame import DataFrame
#      74 from pandas.core.generic import NDFrame
#      75 from pandas.core.groupby import base
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py in <module>
#     127 )
#     128
# --> 129 from pandas.core import (
#     130     algorithms,
#     131     common as com,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py in <module>
#     120     extract_array,
#     121 )
# --> 122 from pandas.core.describe import describe_ndframe
#     123 from pandas.core.flags import Flags
#     124 from pandas.core.indexes import base as ibase
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\describe.py in <module>
#      35 )
#      36
# ---> 37 from pandas.core.reshape.concat import concat
#      38
#      39 from pandas.io.formats.format import format_percentiles
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\reshape\concat.py in <module>
#      43 )
#      44 import pandas.core.indexes.base as ibase
# ---> 45 from pandas.core.internals import concatenate_managers
#      46
#      47 if TYPE_CHECKING:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\internals\__init__.py in <module>
# ----> 1 from pandas.core.internals.api import make_block  # pseudo-public version
#       2 from pandas.core.internals.array_manager import (
#       3     ArrayManager,
#       4     SingleArrayManager,
#       5 )
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\internals\api.py in <module>
#      11 import numpy as np
#      12
# ---> 13 from pandas._libs.internals import BlockPlacement
#      14 from pandas._typing import Dtype
#      15
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.2032.0_x64__qbz5n2kfra8p0\lib\importlib\_bootstrap.py in parent(self)
#
# KeyboardInterrupt:

# %%
pathInv = "testing.xlsx"
openFileInv = pd.read_excel(pathInv, engine='openpyxl', sheet_name='Sheet1').dropna()

# %%
inv_course_nums = openFileInv['Course Code']
inv_course_names = openFileInv['Course Title']
inv_exam_dates = openFileInv['Date']
inv_exam_start = openFileInv['Start Time']
inv_exam_end = openFileInv['End Time']
ic_names = openFileInv['IC Name']
ic_emails = openFileInv['IC Email']
inv_names = openFileInv['Invigilator Name']
inv_emails = openFileInv['Invigilator Email']

# print(inv_course_nums, inv_names, inv_course_names, inv_exam_dates, inv_exam_start, inv_exam_end, ic_names, ic_emails, inv_emails)
print(ic_emails)
# Out:
# 0          LAVANYA@HYDERABAD.BITS-PILANI.AC.IN
# 1          PRANESH@HYDERABAD.BITS-PILANI.AC.IN
# 2    ANHITIPATNAIK@HYDERABAD.BITS-PILANI.AC.IN
# 3        MAYAVINAI@HYDERABAD.BITS-PILANI.AC.IN
# 4        BISWANATH@HYDERABAD.BITS-PILANI.AC.IN
# Name: IC Email, dtype: object

# %%
email = "td@hyderabad.bits-pilani.ac.in"
password = ""
server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
server.ehlo()
server.login(email, password)
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# <ipython-input-5-6e008cf96dce> in <module>
#       3 server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
#       4 server.ehlo()
# ----> 5 server.login(email, password)
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     741
#     742         # We could not login successfully.  Return result of last attempt.
# --> 743         raise last_exception
#     744
#     745     def starttls(self, keyfile=None, certfile=None, context=None):
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     730             method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     731             try:
# --> 732                 (code, resp) = self.auth(
#     733                     authmethod, getattr(self, method_name),
#     734                     initial_response_ok=initial_response_ok)
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\smtplib.py in auth(self, mechanism, authobject, initial_response_ok)
#     653         if code in (235, 503):
#     654             return (code, resp)
# --> 655         raise SMTPAuthenticationError(code, resp)
#     656
#     657     def auth_cram_md5(self, challenge=None):
#
# SMTPAuthenticationError: (501, b'5.5.2 Cannot Decode response h4sm9077908pjm.14 - gsmtp')

# %%
i = 0
from email.mime.multipart import MIMEMultipart
while i < len(ic_emails):
    dictn = {
        "Course ID" : [],
        "Course Name" : [],
        "Exam Date" : [],
        "Start Time" : [],
        "End Time"  : [],
        "Invigilator Name" : [],
        "Invigilator Email" : [],
    }
    while(i < len(ic_emails) - 1 and ic_emails[i] == ic_emails[i+1]):
        dictn["Course ID"].append(inv_course_nums[i])
        dictn["Course Name"].append(inv_course_names[i])
        dictn["Exam Date"].append(str(inv_exam_dates[i])[0:11])
        dictn["Start Time"].append(str(inv_exam_start[i]))
        dictn["End Time"].append(str(inv_exam_end[i]))
        dictn["Invigilator Name"].append(inv_names[i])
        dictn["Invigilator Email"].append(inv_emails[i])
        i = i + 1
    dictn["Course ID"].append(inv_course_nums[i])
    dictn["Course Name"].append(inv_course_names[i])
    dictn["Exam Date"].append(str(inv_exam_dates[i])[0:11])
    dictn["Start Time"].append(str(inv_exam_start[i]))
    dictn["End Time"].append(str(inv_exam_end[i]))
    dictn["Invigilator Name"].append(inv_names[i])
    dictn["Invigilator Email"].append(inv_emails[i])
    data = pd.DataFrame(dictn)
    print(data)
    print('----------------------------------------------------------')
    msg = f'Dear {ic_names[i]} ,\n\n' \
        f'Please find below the revised list of invigilator(s) for your respective course(s) during mid semester examination.\n'
    end = f'\nRegards,\n' \
        f'FIC, Timetable & Exam\n' \
        f'Birla Institute of Technology & Science, Pilani\n' \
        f'Hyderabad Campus\n' \
        f'Jawahar Nagar, Kapra Mandal\n' \
        f'Hyderabad 500 078, Telangana, India\n' \
        f'Phone: +91-40 66303802\n' \
        f'Email: timetable@hyderabad.bits-pilani.ac.in\n' \
    
    message = MIMEMultipart()
    message['Subject'] = 'REVISED: Invigilator List'
    message['From'] = email
    output = build_table(data, 'blue_light')
    body_content = output
    message.attach(MIMEText(msg, "plain"))
    message.attach(MIMEText(body_content, "html"))
    message.attach(MIMEText(end, "plain"))
    msg_body = message.as_string()
    server.sendmail(email, [ic_emails[i]], msg_body)
    print('mail sent ' + str(i))
    time.sleep(1)
    i = i + 1
# Out:
#   Course ID          Course Name    Exam Date Start Time  End Time  \
# 0   GS F242     CULTURAL STUDIES  2021-10-21    13:30:00  15:00:00
# 1   GS F242     CULTURAL STUDIES  2021-10-21    13:30:00  15:00:00
# 2   GS F242     CULTURAL STUDIES  2021-10-21    13:30:00  15:00:00
# 3  HSS F244  CRIME AND NEW MEDIA  2021-10-22    15:30:00  17:00:00
# 4  HSS F244  CRIME AND NEW MEDIA  2021-10-22    15:30:00  17:00:00
# 5  HSS F244  CRIME AND NEW MEDIA  2021-10-22    15:30:00  17:00:00
# 6  HSS F244  CRIME AND NEW MEDIA  2021-10-22    15:30:00  17:00:00
#
#        Invigilator Name                          Invigilator Email
# 0        ANHITI PATNAIK  ANHITIPATNAIK@HYDERABAD.BITS-PILANI.AC.IN
# 1       AHMED SHABIN KK     p20180440@ hyderabad.bits-pilani.ac.in
# 2             NANDANA R     p20200034@ hyderabad.bits-pilani.ac.in
# 3        ANHITI PATNAIK  ANHITIPATNAIK@HYDERABAD.BITS-PILANI.AC.IN
# 4     K LAKSHMI JAHNAVI     p20150007@ hyderabad.bits-pilani.ac.in
# 5  REVATHY HEMACHANDRAN     p20170018@ hyderabad.bits-pilani.ac.in
# 6      MD SHAHID AKHTER     p20180437@ hyderabad.bits-pilani.ac.in
# ----------------------------------------------------------
# mail sent 6
#   Course ID             Course Name    Exam Date Start Time  End Time  \
# 0   GS F221  BUSINESS COMMUNICATION  2021-10-22    15:30:00  17:00:00
# 1   GS F221  BUSINESS COMMUNICATION  2021-10-22    15:30:00  17:00:00
# 2   GS F221  BUSINESS COMMUNICATION  2021-10-22    15:30:00  17:00:00
# 3   GS F221  BUSINESS COMMUNICATION  2021-10-22    15:30:00  17:00:00
# 4  HSS F334    SRIMAD BHAGAVAD GITA  2021-10-18    15:30:00  17:00:00
# 5  HSS F334    SRIMAD BHAGAVAD GITA  2021-10-18    15:30:00  17:00:00
# 6  HSS F334    SRIMAD BHAGAVAD GITA  2021-10-18    15:30:00  17:00:00
# 7  HSS F334    SRIMAD BHAGAVAD GITA  2021-10-18    15:30:00  17:00:00
#
#         Invigilator Name                       Invigilator Email
# 0            Aruna Lolla       ARUNA@HYDERABAD.BITS-PILANI.AC.IN
# 1         VINAY SANKAR P  p20170422@ hyderabad.bits-pilani.ac.in
# 2              ROHIT JHA  p20170439@ hyderabad.bits-pilani.ac.in
# 3            Jaya Sarkar  p20180439@ hyderabad.bits-pilani.ac.in
# 4            Aruna Lolla       ARUNA@HYDERABAD.BITS-PILANI.AC.IN
# 5              ROHIT JHA  p20170439@ hyderabad.bits-pilani.ac.in
# 6       MD SHAHID AKHTER  p20180437@ hyderabad.bits-pilani.ac.in
# 7  AMRIT AMLAN PATTANAIK  p20200447@ hyderabad.bits-pilani.ac.in
# ----------------------------------------------------------
# mail sent 14
#   Course ID               Course Name    Exam Date Start Time  End Time  \
# 0  HSS F363  DISASTER AND DEVELOPMENT  2021-10-22    09:00:00  22:30:00
# 1  HSS F363  DISASTER AND DEVELOPMENT  2021-10-22    09:00:00  22:30:00
# 2  HSS F363  DISASTER AND DEVELOPMENT  2021-10-22    09:00:00  22:30:00
# 3  HSS F363  DISASTER AND DEVELOPMENT  2021-10-22    09:00:00  22:30:00
#
#      Invigilator Name                       Invigilator Email
# 0      BISWANATH DASH   BISWANATH@HYDERABAD.BITS-PILANI.AC.IN
# 1   K LAKSHMI JAHNAVI  p20150007@ hyderabad.bits-pilani.ac.in
# 2     AHMED SHABIN KK  p20180440@ hyderabad.bits-pilani.ac.in
# 3  M V GIRINATH REDDY  p20210038@ hyderabad.bits-pilani.ac.in
# ----------------------------------------------------------
# mail sent 18
#   Course ID              Course Name    Exam Date Start Time  End Time  \
# 0  HSS F246  PHILOSOPHY OF NAGARJUNA  2021-10-18    15:30:00  17:00:00
# 1  HSS F246  PHILOSOPHY OF NAGARJUNA  2021-10-18    15:30:00  17:00:00
# 2  HSS F343      PROFESSIONAL ETHICS  2021-10-21    15:30:00  17:00:00
# 3  HSS F343      PROFESSIONAL ETHICS  2021-10-21    15:30:00  17:00:00
# 4  HSS F343      PROFESSIONAL ETHICS  2021-10-21    15:30:00  17:00:00
# 5  HSS F343      PROFESSIONAL ETHICS  2021-10-21    15:30:00  17:00:00
#
#     Invigilator Name                       Invigilator Email
# 0         JAYESH A K      JAYESH@HYDERABAD.BITS-PILANI.AC.IN
# 1       PRASUNA M G      PRASUNA@HYDERABAD.BITS-PILANI.AC.IN
# 2         JAYESH A K      JAYESH@HYDERABAD.BITS-PILANI.AC.IN
# 3     VINAY SANKAR P  p20170422@ hyderabad.bits-pilani.ac.in
# 4   KRITHIKA NAMBIAR  p20190436@ hyderabad.bits-pilani.ac.in
# 5  SANTOSH MAHAPATRA     SANTOSH@HYDERABAD.BITS-PILANI.AC.IN
# ----------------------------------------------------------
# mail sent 24
#   Course ID                     Course Name    Exam Date Start Time  End Time  \
# 0   GS F212        ENVIRON DEV & CLIMATE CH  2021-10-23    13:30:00  15:00:00
# 1   GS F212        ENVIRON DEV & CLIMATE CH  2021-10-23    13:30:00  15:00:00
# 2   GS F212        ENVIRON DEV & CLIMATE CH  2021-10-23    13:30:00  15:00:00
# 3   GS F212        ENVIRON DEV & CLIMATE CH  2021-10-23    13:30:00  15:00:00
# 4  HSS F362  LOCAL GOVERNANCE AND PARTICIPA  2021-10-21    15:30:00  17:00:00
# 5  HSS F362  LOCAL GOVERNANCE AND PARTICIPA  2021-10-21    15:30:00  17:00:00
# 6  HSS F362  LOCAL GOVERNANCE AND PARTICIPA  2021-10-21    15:30:00  17:00:00
#
#        Invigilator Name                       Invigilator Email
# 0        LAVANYA SURESH     LAVANYA@HYDERABAD.BITS-PILANI.AC.IN
# 1     K LAKSHMI JAHNAVI  p20150007@ hyderabad.bits-pilani.ac.in
# 2  REVATHY HEMACHANDRAN  p20170018@ hyderabad.bits-pilani.ac.in
# 3        VINAY SANKAR P  p20170422@ hyderabad.bits-pilani.ac.in
# 4        LAVANYA SURESH     LAVANYA@HYDERABAD.BITS-PILANI.AC.IN
# 5          NAVYA KUMAR    P20190426@HYDERABAD.BITS-PILANI.AC.IN
# 6    M V GIRINATH REDDY  p20210038@ hyderabad.bits-pilani.ac.in
# ----------------------------------------------------------
# mail sent 31
#   Course ID         Course Name    Exam Date Start Time  End Time  \
# 0  HSS F331  SANKARA’S THOUGHTS  2021-10-18    15:30:00  17:00:00
# 1  HSS F331  SANKARA’S THOUGHTS  2021-10-18    15:30:00  17:00:00
# 2  HSS F331  SANKARA’S THOUGHTS  2021-10-18    15:30:00  17:00:00
#
#     Invigilator Name                       Invigilator Email
# 0        MAYA VINAI    MAYAVINAI@HYDERABAD.BITS-PILANI.AC.IN
# 1  K LAKSHMI JAHNAVI  p20150007@ hyderabad.bits-pilani.ac.in
# 2        MITHUNA S M  p20200450@ hyderabad.bits-pilani.ac.in
# ----------------------------------------------------------
# mail sent 34
#   Course ID  Course Name    Exam Date Start Time  End Time  \
# 0  HSS F222  LINGUISTICS  2021-10-21    15:30:00  17:00:00
# 1  HSS F222  LINGUISTICS  2021-10-21    15:30:00  17:00:00
# 2  HSS F222  LINGUISTICS  2021-10-21    15:30:00  17:00:00
#
#        Invigilator Name                       Invigilator Email
# 0     K LAKSHMI JAHNAVI  p20150007@ hyderabad.bits-pilani.ac.in
# 1  REVATHY HEMACHANDRAN  p20170018@ hyderabad.bits-pilani.ac.in
# 2      PRANESH BHARGAVA     PRANESH@HYDERABAD.BITS-PILANI.AC.IN
# ----------------------------------------------------------
# mail sent 37
#   Course ID               Course Name    Exam Date Start Time  End Time  \
# 0   GS F322  CRITI ANAL OF LIT & CINE  2021-10-21    15:30:00  17:00:00
# 1   GS F322  CRITI ANAL OF LIT & CINE  2021-10-21    15:30:00  17:00:00
# 2   GS F322  CRITI ANAL OF LIT & CINE  2021-10-21    15:30:00  17:00:00
# 3   GS F322  CRITI ANAL OF LIT & CINE  2021-10-21    15:30:00  17:00:00
#
#         Invigilator Name                       Invigilator Email
# 0              ROHIT JHA  p20170439@ hyderabad.bits-pilani.ac.in
# 1  AMRIT AMLAN PATTANAIK  p20200447@ hyderabad.bits-pilani.ac.in
# 2            MITHUNA S M  p20200450@ hyderabad.bits-pilani.ac.in
# 3           PRASUNA M G      PRASUNA@HYDERABAD.BITS-PILANI.AC.IN
# ----------------------------------------------------------
# mail sent 41
#   Course ID             Course Name    Exam Date Start Time  End Time  \
# 0   GS F245  EFFECTIVE PUBLIC SPEAK  2021-10-18    15:30:00  17:00:00
# 1   GS F245  EFFECTIVE PUBLIC SPEAK  2021-10-18    15:30:00  17:00:00
# 2   GS F245  EFFECTIVE PUBLIC SPEAK  2021-10-18    15:30:00  17:00:00
# 3   GS F245  EFFECTIVE PUBLIC SPEAK  2021-10-18    15:30:00  17:00:00
#
#        Invigilator Name                       Invigilator Email
# 0       AHMED SHABIN KK  p20180440@ hyderabad.bits-pilani.ac.in
# 1  S SARITHA SASIDHARAN  p20190059@ hyderabad.bits-pilani.ac.in
# 2             NANDANA R  p20200034@ hyderabad.bits-pilani.ac.in
# 3     SANTOSH MAHAPATRA     SANTOSH@HYDERABAD.BITS-PILANI.AC.IN
# ----------------------------------------------------------
# mail sent 45
#   Course ID                     Course Name    Exam Date Start Time  End Time  \
# 0  HSS F248  INTRODUCTION TO DISABILITY STU  2021-10-23    13:30:00  15:00:00
# 1  HSS F248  INTRODUCTION TO DISABILITY STU  2021-10-23    13:30:00  15:00:00
# 2  HSS F248  INTRODUCTION TO DISABILITY STU  2021-10-23    13:30:00  15:00:00
# 3  HSS F248  INTRODUCTION TO DISABILITY STU  2021-10-23    13:30:00  15:00:00
# 4  HSS F335              LITERARY CRITICISM  2021-10-18    15:30:00  17:00:00
# 5  HSS F335              LITERARY CRITICISM  2021-10-18    15:30:00  17:00:00
# 6  HSS F335              LITERARY CRITICISM  2021-10-18    15:30:00  17:00:00
# 7  HSS F335              LITERARY CRITICISM  2021-10-18    15:30:00  17:00:00
#
#      Invigilator Name                          Invigilator Email
# 0           ROHIT JHA     p20170439@ hyderabad.bits-pilani.ac.in
# 1     AHMED SHABIN KK     p20180440@ hyderabad.bits-pilani.ac.in
# 2  M V GIRINATH REDDY     p20210038@ hyderabad.bits-pilani.ac.in
# 3       SHILPAA ANAND  SHILPAA.ANAND@HYDERABAD.BITS-PILANI.AC.IN
# 4         Jaya Sarkar     p20180439@ hyderabad.bits-pilani.ac.in
# 5    KRITHIKA NAMBIAR     p20190436@ hyderabad.bits-pilani.ac.in
# 6  M V GIRINATH REDDY     p20210038@ hyderabad.bits-pilani.ac.in
# 7       SHILPAA ANAND  SHILPAA.ANAND@HYDERABAD.BITS-PILANI.AC.IN
# ----------------------------------------------------------
# mail sent 53
#   Course ID         Course Name    Exam Date Start Time  End Time  \
# 0   GS F223  INTRO TO MASS COMM  2021-10-21    15:30:00  17:00:00
# 1   GS F223  INTRO TO MASS COMM  2021-10-21    15:30:00  17:00:00
# 2   GS F223  INTRO TO MASS COMM  2021-10-21    15:30:00  17:00:00
# 3  HSS F332       CINEMATIC ART  2021-10-18    15:30:00  17:00:00
# 4  HSS F332       CINEMATIC ART  2021-10-18    15:30:00  17:00:00
# 5  HSS F332       CINEMATIC ART  2021-10-18    15:30:00  17:00:00
# 6  HSS F332       CINEMATIC ART  2021-10-18    15:30:00  17:00:00
#
#         Invigilator Name                       Invigilator Email
# 0       MD SHAHID AKHTER  p20180437@ hyderabad.bits-pilani.ac.in
# 1            Jaya Sarkar  p20180439@ hyderabad.bits-pilani.ac.in
# 2  SPANDAN BHATTACHARYA      SPANDAN@HYDERABAD.BITS-PILANI.AC.IN
# 3   REVATHY HEMACHANDRAN  p20170018@ hyderabad.bits-pilani.ac.in
# 4         VINAY SANKAR P  p20170422@ hyderabad.bits-pilani.ac.in
# 5           NAVYA KUMAR    P20190426@HYDERABAD.BITS-PILANI.AC.IN
# 6  SPANDAN BHATTACHARYA      SPANDAN@HYDERABAD.BITS-PILANI.AC.IN
# ----------------------------------------------------------
# mail sent 60
#   Course ID              Course Name    Exam Date Start Time  End Time  \
# 0  HSS F318    INTRO TO ANTHROPOLOGY  2021-10-21    15:30:00  17:00:00
# 1  HSS F318    INTRO TO ANTHROPOLOGY  2021-10-21    15:30:00  17:00:00
# 2  HSS F318    INTRO TO ANTHROPOLOGY  2021-10-21    15:30:00  17:00:00
# 3  HSS F346  INTERNATIONAL RELATIONS  2021-10-22    15:30:00  17:00:00
# 4  HSS F346  INTERNATIONAL RELATIONS  2021-10-22    15:30:00  17:00:00
# 5  HSS F346  INTERNATIONAL RELATIONS  2021-10-22    15:30:00  17:00:00
# 6  HSS F346  INTERNATIONAL RELATIONS  2021-10-22    15:30:00  17:00:00
#
#        Invigilator Name                       Invigilator Email
# 0  S SARITHA SASIDHARAN  p20190059@ hyderabad.bits-pilani.ac.in
# 1             NANDANA R  p20200034@ hyderabad.bits-pilani.ac.in
# 2   SUCHISMITA SATPATHY       SUCHI@HYDERABAD.BITS-PILANI.AC.IN
# 3           MAYA VINAI    MAYAVINAI@HYDERABAD.BITS-PILANI.AC.IN
# 4             NANDANA R  p20200034@ hyderabad.bits-pilani.ac.in
# 5           MITHUNA S M  p20200450@ hyderabad.bits-pilani.ac.in
# 6   SUCHISMITA SATPATHY       SUCHI@HYDERABAD.BITS-PILANI.AC.IN
# ----------------------------------------------------------
# mail sent 67
#   Course ID             Course Name    Exam Date Start Time  End Time  \
# 0  HSS F328  HUMAN RESOURCE DEVELOP  2021-10-22    15:30:00  17:00:00
# 1  HSS F328  HUMAN RESOURCE DEVELOP  2021-10-22    15:30:00  17:00:00
# 2  HSS F328  HUMAN RESOURCE DEVELOP  2021-10-22    15:30:00  17:00:00
# 3  HSS F328  HUMAN RESOURCE DEVELOP  2021-10-22    15:30:00  17:00:00
#
#         Invigilator Name                       Invigilator Email
# 0   S SARITHA SASIDHARAN  p20190059@ hyderabad.bits-pilani.ac.in
# 1           NAVYA KUMAR    P20190426@HYDERABAD.BITS-PILANI.AC.IN
# 2  AMRIT AMLAN PATTANAIK  p20200447@ hyderabad.bits-pilani.ac.in
# 3            Swati Alok        SWATI@HYDERABAD.BITS-PILANI.AC.IN
# ----------------------------------------------------------
# mail sent 71
